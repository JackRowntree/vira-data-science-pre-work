# %% [markdown]
# ## Summary
#
# Thank you for your interest in Vira Health's data science team!
#
# This jupyter notebook contains instructions for a short task which will give you an insight into some of what Vira Health is working on.
#
# The task is structured around building a simple 1 page dashboard that summarises what you think are the key characteristics of the datasets provided.
#
# Data provided is courtesy of the Study of Women's Health Across the Nation (SWAN) and is publically available from their [website](https://www.swanstudy.org/).
#
# Additional documentation can be found in the ICPSR data repository [here](https://www.icpsr.umich.edu/web/ICPSR/series/00253) and may be helpful to support completion of the task.

# %% [markdown]
# ## Step 1: Data exploration
#
# The /data folder includes data from a questionnaire collected at baseline ("swan_1996_97_baseline.csv") and two annual follow-up visits ("swan_1997_99_visit1.csv", "swan_1998_00_visit2.csv").
#
# Documentation for the baseline visit with details of the questionnaire and variables referenced is also included in the /data folder as "baseline-visit-codebook-PI.pdf".
#
# As a first step, please load in the data in this python notebook and conduct whatever exploration you need to decide - **"What are the key characteristics of these datasets?"**.
#
# To help focus, remember that the overall aim of the task is to **build a simple 1 page dashboard that summarises the key characteristics of the datasets**.
#
# Example exploration could include answering sub-questions such as, what is the size of each sample? how many participants have data in all follow-up visits?
#
# Please include inline code comments or markdown to explain your approach.
#
# Note, this exploration is not expected to be comprehensive, but if there are further analyses you would conduct to help you understand these datasets please include them in your commentary and explain what you would do.

# %% [markdown]
# # Summary of response

# %% [markdown]
# Overall, my strategy is:
# 1. Clean the data up into a state suitable for interrogation by data consumers (e.g. nulls cleaned, datetimes converted), who can then theoretically come up with detailed requirements for what to do with this dataset
# 2. Produce some a data quality dashboard to for data consumers to use in conjunction with the data itself
#
# The idea being that data consumers would then be in a position to iteratively make data engineering requirements for this dataset.

# %% [markdown]
# ## 0. Install dependencies

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (1.2.4)
# Collecting plotly
#   Using cached plotly-5.13.1-py2.py3-none-any.whl (15.2 MB)
# Collecting jupyter-dash
#   Using cached jupyter_dash-0.4.2-py3-none-any.whl (23 kB)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (20.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 1)) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 1)) (1.20.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 1)) (1.16.0)
# Collecting tenacity>=6.2.0
#   Using cached tenacity-8.2.1-py3-none-any.whl (24 kB)
# Collecting flask
#   Using cached Flask-2.2.3-py3-none-any.whl (101 kB)
# Collecting dash
#   Using cached dash-2.8.1-py3-none-any.whl (9.9 MB)
# Collecting ansi2html
#   Using cached ansi2html-1.8.0-py3-none-any.whl (16 kB)
# Collecting retrying
#   Using cached retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.9/site-packages (from jupyter-dash->-r requirements.txt (line 3)) (7.23.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.9/site-packages (from jupyter-dash->-r requirements.txt (line 3)) (2.25.1)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.9/site-packages (from jupyter-dash->-r requirements.txt (line 3)) (5.5.5)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.9/site-packages (from jupyter-dash->-r requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.9/site-packages (from packaging->-r requirements.txt (line 4)) (2.4.7)
# Collecting dash-core-components==2.0.0
#   Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0
#   Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting dash-html-components==2.0.0
#   Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting itsdangerous>=2.0
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting click>=8.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /opt/conda/lib/python3.9/site-packages (from flask->jupyter-dash->-r requirements.txt (line 3)) (4.0.1)
# Requirement already satisfied: Jinja2>=3.0 in /opt/conda/lib/python3.9/site-packages (from flask->jupyter-dash->-r requirements.txt (line 3)) (3.0.1)
# Collecting Werkzeug>=2.2.2
#   Using cached Werkzeug-2.2.3-py3-none-any.whl (233 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.9/site-packages (from importlib-metadata>=3.6.0->flask->jupyter-dash->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.9/site-packages (from Jinja2>=3.0->flask->jupyter-dash->-r requirements.txt (line 3)) (2.0.1)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Requirement already satisfied: tornado>=4.2 in /opt/conda/lib/python3.9/site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 3)) (6.1)
# Requirement already satisfied: traitlets>=4.1.0 in /opt/conda/lib/python3.9/site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 3)) (5.0.5)
# Requirement already satisfied: jupyter-client in /opt/conda/lib/python3.9/site-packages (from ipykernel->jupyter-dash->-r requirements.txt (line 3)) (6.1.12)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.9/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.9/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 3)) (2.9.0)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.9/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 3)) (0.18.0)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.9/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.9/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 3)) (49.6.0.post20210108)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.9/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.9/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.9/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 3)) (5.0.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.9/site-packages (from ipython->jupyter-dash->-r requirements.txt (line 3)) (3.0.18)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.9/site-packages (from jedi>=0.16->ipython->jupyter-dash->-r requirements.txt (line 3)) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.9/site-packages (from pexpect>4.3->ipython->jupyter-dash->-r requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash->-r requirements.txt (line 3)) (0.2.5)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.9/site-packages (from traitlets>=4.1.0->ipykernel->jupyter-dash->-r requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: pyzmq>=13 in /opt/conda/lib/python3.9/site-packages (from jupyter-client->ipykernel->jupyter-dash->-r requirements.txt (line 3)) (22.0.3)
# Requirement already satisfied: jupyter-core>=4.6.0 in /opt/conda/lib/python3.9/site-packages (from jupyter-client->ipykernel->jupyter-dash->-r requirements.txt (line 3)) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.9/site-packages (from requests->jupyter-dash->-r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.9/site-packages (from requests->jupyter-dash->-r requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.9/site-packages (from requests->jupyter-dash->-r requirements.txt (line 3)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.9/site-packages (from requests->jupyter-dash->-r requirements.txt (line 3)) (2020.12.5)
# Installing collected packages: MarkupSafe, Werkzeug, tenacity, itsdangerous, click, plotly, flask, dash-table, dash-html-components, dash-core-components, retrying, dash, ansi2html, jupyter-dash
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# Successfully installed MarkupSafe-2.1.2 Werkzeug-2.2.3 ansi2html-1.8.0 click-8.1.3 dash-2.8.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 flask-2.2.3 itsdangerous-2.1.2 jupyter-dash-0.4.2 plotly-5.13.1 retrying-1.3.4 tenacity-8.2.1

# %% [markdown]
# # 1. Import packages

# %%
import pandas as pd
import re
import numpy as np

# %% [markdown]
# # 2. Load data

# %%
baseline_df = pd.read_csv("data/swan_1996_97_baseline.csv")
visit1_df = pd.read_csv("data/swan_1997_99_visit1.csv")
visit2_df = pd.read_csv("data/swan_1998_00_visit2.csv")
dfs = {'baseline_df': baseline_df, 'visit1_df': visit1_df,'visit2_df': visit2_df}
# Out:
# /opt/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (119,215,261) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (25,33,37,51,52,53,57,103,104,105,106,147,148,149,150,151,152,153,154,209,211,267,270) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /opt/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (25,53,57,67,75,77,99,100,101,102,103,104,105,106,107,159,160,161,162,163,164,165,166,167,210,227,494) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # 3. Get idea of scale of data

# %%
for name, df in dfs.items():
    print(f'{name} dims: {df.shape}')
# Out:
# baseline_df dims: (3302, 741)
# visit1_df dims: (2881, 576)
# visit2_df dims: (2748, 551)

# %% [markdown]
# Couple things are apparent here:
#    1. The data is _very_ wide. Due to the width of the data, its easiest to get a taste for what's going on outside of the notebook - Excel will suit fine in this case of csvs on disk. If the location differed, we could choose a different solution (e.g. AWS Athena for S3 data, RDBMS for data in a database, etc.)
#    2. The number of rows decreases from baseline -> 2nd visit, whether this is due to inherent dropoff in the dataset or a potential issue is unknown at this stage
#    3. The number of columns decreases similarly.
#
# Action points at this stage after getting eyes on data in excel:
# 1. Each table has column suffixes which we may or may not want to remove
# 2. We have a lot of text data that needs transforming into binary/category variables
# 3. We have a lot of 'NA' strings that need cleaning

# %% [markdown]
# ### Handling text data

# %% [markdown]
# Given my current lack of understanding of the data, I will leave multicardinal (?) survey results as is until a requirement is given to change them. However, we can convert binary text columns to boolean for sure and save some memory

# %%
def _convert_bools(df):
    out_df = df.copy()
    for col in df.columns:
        if list(df[col][df[col].notna()].unique()) == ['(1) No', '(2) Yes' ]:
             out_df[col] = out_df[col].map({'(1) No': 0, '(2) Yes' :1}).astype("boolean")
    return out_df

def convert_bools(dict_of_dfs):
    out = {}
    for name,df in dfs.items():
        out[name] =_convert_bools(df)  
    return out

# %% [markdown]
# ### Handling missing values

# %% [markdown]
# Luckily pandas assumes 'NA' = NaN. But we still have other examples of missing data:

# %%
def strip_whitespace(dict_of_dfs):
    out = {}
    for name,df in dfs.items():
        out[name] = _strip_whitespace(df)
    return out

def _strip_whitespace(df):
    out_df = df.copy()
    for col in out_df.loc[:, out_df.dtypes == object].columns:
        out_df[col] = out_df[col].str.strip(' ')
    return out_df

def clean_nans(dict_of_dfs):
    out = {}
    for name,df in dfs.items():
        out[name] = _clean_nans(df)
    return out

def _clean_nans(df):
    out_df = df.copy()
    for col in out_df.loc[:, out_df.dtypes == object].columns:
        if out_df[col].isin(['.','', '-1']).any():
            out_df[col] = out_df[col].replace({'.' : np.nan, '':np.nan, '-1':np.nan})
    return out_df

# %% [markdown]
# NB _clean_nans()_ should be safe for cols like LMPDAY0 which have negative integer values, and are not read as object.

# %% [markdown]
# ### Converting datetimes

# %% [markdown]
# Any datetimes with /?

# %%
for name,df in dfs.items():
    for col in df.columns:
        if df[col].dtype == 'object':
            if df[col].str.contains('/').any():
                print(df[col])
# Out:
# 0       (1) Yes, as per protocol
# 1       (1) Yes, as per protocol
# 2       (1) Yes, as per protocol
# 3       (1) Yes, as per protocol
# 4       (1) Yes, as per protocol
#                   ...
# 3297    (1) Yes, as per protocol
# 3298    (1) Yes, as per protocol
# 3299       (3) Yes, Last attempt
# 3300    (1) Yes, as per protocol
# 3301    (1) Yes, as per protocol
# Name: BLDRWAT0, Length: 3302, dtype: object
# 0       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 1              (2) Some/A Little Of The Time (1-2 Days)
# 2              (2) Some/A Little Of The Time (1-2 Days)
# 3              (2) Some/A Little Of The Time (1-2 Days)
# 4              (2) Some/A Little Of The Time (1-2 Days)
#                              ...
# 3297           (2) Some/A Little Of The Time (1-2 Days)
# 3298              (1) Rarely/None Of The Time (< 1 Day)
# 3299              (1) Rarely/None Of The Time (< 1 Day)
# 3300              (1) Rarely/None Of The Time (< 1 Day)
# 3301              (1) Rarely/None Of The Time (< 1 Day)
# Name: BOTHER0, Length: 3302, dtype: object
# 0            (4) Most/All Of The Time (5-7 Days)
# 1          (1) Rarely/None Of The Time (< 1 Day)
# 2          (1) Rarely/None Of The Time (< 1 Day)
# 3          (1) Rarely/None Of The Time (< 1 Day)
# 4          (1) Rarely/None Of The Time (< 1 Day)
#                           ...
# 3297       (1) Rarely/None Of The Time (< 1 Day)
# 3298       (1) Rarely/None Of The Time (< 1 Day)
# 3299       (1) Rarely/None Of The Time (< 1 Day)
# 3300       (1) Rarely/None Of The Time (< 1 Day)
# 3301    (2) Some/A Little Of The Time (1-2 Days)
# Name: APPETIT0, Length: 3302, dtype: object
# 0                   (4) Most/All Of The Time (5-7 Days)
# 1                 (1) Rarely/None Of The Time (< 1 Day)
# 2                 (1) Rarely/None Of The Time (< 1 Day)
# 3                 (1) Rarely/None Of The Time (< 1 Day)
# 4       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
#                              ...
# 3297           (2) Some/A Little Of The Time (1-2 Days)
# 3298              (1) Rarely/None Of The Time (< 1 Day)
# 3299           (2) Some/A Little Of The Time (1-2 Days)
# 3300              (1) Rarely/None Of The Time (< 1 Day)
# 3301              (1) Rarely/None Of The Time (< 1 Day)
# Name: BLUES0, Length: 3302, dtype: object
# 0                   (4) Most/All Of The Time (5-7 Days)
# 1                   (4) Most/All Of The Time (5-7 Days)
# 2                   (4) Most/All Of The Time (5-7 Days)
# 3       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 4                   (4) Most/All Of The Time (5-7 Days)
#                              ...
# 3297                (4) Most/All Of The Time (5-7 Days)
# 3298                (4) Most/All Of The Time (5-7 Days)
# 3299                (4) Most/All Of The Time (5-7 Days)
# 3300                (4) Most/All Of The Time (5-7 Days)
# 3301                (4) Most/All Of The Time (5-7 Days)
# Name: GOOD0, Length: 3302, dtype: object
# 0       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 1                 (1) Rarely/None Of The Time (< 1 Day)
# 2       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 3       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 4       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
#                              ...
# 3297    (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 3298              (1) Rarely/None Of The Time (< 1 Day)
# 3299              (1) Rarely/None Of The Time (< 1 Day)
# 3300              (1) Rarely/None Of The Time (< 1 Day)
# 3301                (4) Most/All Of The Time (5-7 Days)
# Name: KEEPMIN0, Length: 3302, dtype: object
# 0            (4) Most/All Of The Time (5-7 Days)
# 1          (1) Rarely/None Of The Time (< 1 Day)
# 2          (1) Rarely/None Of The Time (< 1 Day)
# 3          (1) Rarely/None Of The Time (< 1 Day)
# 4            (4) Most/All Of The Time (5-7 Days)
#                           ...
# 3297    (2) Some/A Little Of The Time (1-2 Days)
# 3298       (1) Rarely/None Of The Time (< 1 Day)
# 3299    (2) Some/A Little Of The Time (1-2 Days)
# 3300       (1) Rarely/None Of The Time (< 1 Day)
# 3301         (4) Most/All Of The Time (5-7 Days)
# Name: DEPRESS0, Length: 3302, dtype: object
# 0                   (4) Most/All Of The Time (5-7 Days)
# 1              (2) Some/A Little Of The Time (1-2 Days)
# 2              (2) Some/A Little Of The Time (1-2 Days)
# 3                 (1) Rarely/None Of The Time (< 1 Day)
# 4                   (4) Most/All Of The Time (5-7 Days)
#                              ...
# 3297    (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 3298              (1) Rarely/None Of The Time (< 1 Day)
# 3299              (1) Rarely/None Of The Time (< 1 Day)
# 3300           (2) Some/A Little Of The Time (1-2 Days)
# 3301    (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# Name: EFFORT0, Length: 3302, dtype: object
# 0       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 1                   (4) Most/All Of The Time (5-7 Days)
# 2                   (4) Most/All Of The Time (5-7 Days)
# 3       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 4              (2) Some/A Little Of The Time (1-2 Days)
#                              ...
# 3297           (2) Some/A Little Of The Time (1-2 Days)
# 3298                (4) Most/All Of The Time (5-7 Days)
# 3299    (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 3300                (4) Most/All Of The Time (5-7 Days)
# 3301                (4) Most/All Of The Time (5-7 Days)
# Name: HOPEFUL0, Length: 3302, dtype: object
# 0       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 1                 (1) Rarely/None Of The Time (< 1 Day)
# 2                 (1) Rarely/None Of The Time (< 1 Day)
# 3                 (1) Rarely/None Of The Time (< 1 Day)
# 4       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
#                              ...
# 3297    (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 3298              (1) Rarely/None Of The Time (< 1 Day)
# 3299              (1) Rarely/None Of The Time (< 1 Day)
# 3300              (1) Rarely/None Of The Time (< 1 Day)
# 3301           (2) Some/A Little Of The Time (1-2 Days)
# Name: FAILURE0, Length: 3302, dtype: object
# 0       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 1              (2) Some/A Little Of The Time (1-2 Days)
# 2                 (1) Rarely/None Of The Time (< 1 Day)
# 3                 (1) Rarely/None Of The Time (< 1 Day)
# 4                 (1) Rarely/None Of The Time (< 1 Day)
#                              ...
# 3297    (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 3298              (1) Rarely/None Of The Time (< 1 Day)
# 3299              (1) Rarely/None Of The Time (< 1 Day)
# 3300              (1) Rarely/None Of The Time (< 1 Day)
# 3301              (1) Rarely/None Of The Time (< 1 Day)
# Name: FEARFUL0, Length: 3302, dtype: object
# 0            (4) Most/All Of The Time (5-7 Days)
# 1       (2) Some/A Little Of The Time (1-2 Days)
# 2       (2) Some/A Little Of The Time (1-2 Days)
# 3          (1) Rarely/None Of The Time (< 1 Day)
# 4          (1) Rarely/None Of The Time (< 1 Day)
#                           ...
# 3297       (1) Rarely/None Of The Time (< 1 Day)
# 3298       (1) Rarely/None Of The Time (< 1 Day)
# 3299    (2) Some/A Little Of The Time (1-2 Days)
# 3300       (1) Rarely/None Of The Time (< 1 Day)
# 3301         (4) Most/All Of The Time (5-7 Days)
# Name: RESTLES0, Length: 3302, dtype: object
# 0                 (1) Rarely/None Of The Time (< 1 Day)
# 1       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 2                   (4) Most/All Of The Time (5-7 Days)
# 3       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 4                 (1) Rarely/None Of The Time (< 1 Day)
#                              ...
# 3297           (2) Some/A Little Of The Time (1-2 Days)
# 3298                (4) Most/All Of The Time (5-7 Days)
# 3299           (2) Some/A Little Of The Time (1-2 Days)
# 3300                (4) Most/All Of The Time (5-7 Days)
# 3301              (1) Rarely/None Of The Time (< 1 Day)
# Name: HAPPY0, Length: 3302, dtype: object
# 0          (1) Rarely/None Of The Time (< 1 Day)
# 1            (4) Most/All Of The Time (5-7 Days)
# 2          (1) Rarely/None Of The Time (< 1 Day)
# 3          (1) Rarely/None Of The Time (< 1 Day)
# 4          (1) Rarely/None Of The Time (< 1 Day)
#                           ...
# 3297       (1) Rarely/None Of The Time (< 1 Day)
# 3298       (1) Rarely/None Of The Time (< 1 Day)
# 3299       (1) Rarely/None Of The Time (< 1 Day)
# 3300       (1) Rarely/None Of The Time (< 1 Day)
# 3301    (2) Some/A Little Of The Time (1-2 Days)
# Name: TALKLES0, Length: 3302, dtype: object
# 0       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 1                 (1) Rarely/None Of The Time (< 1 Day)
# 2                 (1) Rarely/None Of The Time (< 1 Day)
# 3                 (1) Rarely/None Of The Time (< 1 Day)
# 4                 (1) Rarely/None Of The Time (< 1 Day)
#                              ...
# 3297           (2) Some/A Little Of The Time (1-2 Days)
# 3298              (1) Rarely/None Of The Time (< 1 Day)
# 3299           (2) Some/A Little Of The Time (1-2 Days)
# 3300              (1) Rarely/None Of The Time (< 1 Day)
# 3301              (1) Rarely/None Of The Time (< 1 Day)
# Name: LONELY0, Length: 3302, dtype: object
# 0       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 1                 (1) Rarely/None Of The Time (< 1 Day)
# 2                 (1) Rarely/None Of The Time (< 1 Day)
# 3                 (1) Rarely/None Of The Time (< 1 Day)
# 4                 (1) Rarely/None Of The Time (< 1 Day)
#                              ...
# 3297              (1) Rarely/None Of The Time (< 1 Day)
# 3298              (1) Rarely/None Of The Time (< 1 Day)
# 3299              (1) Rarely/None Of The Time (< 1 Day)
# 3300              (1) Rarely/None Of The Time (< 1 Day)
# 3301                (4) Most/All Of The Time (5-7 Days)
# Name: UNFRNDL0, Length: 3302, dtype: object
# 0          (1) Rarely/None Of The Time (< 1 Day)
# 1            (4) Most/All Of The Time (5-7 Days)
# 2          (1) Rarely/None Of The Time (< 1 Day)
# 3            (4) Most/All Of The Time (5-7 Days)
# 4       (2) Some/A Little Of The Time (1-2 Days)
#                           ...
# 3297         (4) Most/All Of The Time (5-7 Days)
# 3298         (4) Most/All Of The Time (5-7 Days)
# 3299    (2) Some/A Little Of The Time (1-2 Days)
# 3300         (4) Most/All Of The Time (5-7 Days)
# 3301       (1) Rarely/None Of The Time (< 1 Day)
# Name: ENJOY0, Length: 3302, dtype: object
# 0       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
# 1                 (1) Rarely/None Of The Time (< 1 Day)
# 2                 (1) Rarely/None Of The Time (< 1 Day)
# 3                 (1) Rarely/None Of The Time (< 1 Day)
# 4       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
#                              ...
# 3297              (1) Rarely/None Of The Time (< 1 Day)
# 3298              (1) Rarely/None Of The Time (< 1 Day)
# 3299              (1) Rarely/None Of The Time (< 1 Day)
# 3300              (1) Rarely/None Of The Time (< 1 Day)
# 3301                (4) Most/All Of The Time (5-7 Days)
# Name: CRYING0, Length: 3302, dtype: object
# 0                   (4) Most/All Of The Time (5-7 Days)
# 1                 (1) Rarely/None Of The Time (< 1 Day)
# 2                 (1) Rarely/None Of The Time (< 1 Day)
# 3                 (1) Rarely/None Of The Time (< 1 Day)
# 4       (3) Occasionally/Mod Amt Of The Time (3-4 Days)
#                              ...
# 3297           (2) Some/A Little Of The Time (1-2 Days)
# 3298              (1) Rarely/None Of The Time (< 1 Day)
# 3299           (2) Some/A Little Of The Time (1-2 Days)
# 3300           (2) Some/A Little Of The Time (1-2 Days)
# 3301                (4) Most/All Of The Time (5-7 Days)
# Name: SAD0, Length: 3302, dtype: object
# 0         (4) Most/All Of The Time (5-7 Days)
# 1       (1) Rarely/None Of The Time (< 1 Day)
# 2       (1) Rarely/None Of The Time (< 1 Day)
# 3       (1) Rarely/None Of The Time (< 1 Day)
# 4       (1) Rarely/None Of The Time (< 1 Day)
#                         ...
# 3297    (1) Rarely/None Of The Time (< 1 Day)
# 3298    (1) Rarely/None Of The Time (< 1 Day)
# 3299    (1) Rarely/None Of The Time (< 1 Day)
# 3300    (1) Rarely/None Of The Time (< 1 Day)
# 3301    (1) Rarely/None Of The Time (< 1 Day)
# Name: DISLIKE0, Length: 3302, dtype: object
# 0            (4) Most/All Of The Time (5-7 Days)
# 1          (1) Rarely/None Of The Time (< 1 Day)
# 2          (1) Rarely/None Of The Time (< 1 Day)
# 3       (2) Some/A Little Of The Time (1-2 Days)
# 4            (4) Most/All Of The Time (5-7 Days)
#                           ...
# 3297       (1) Rarely/None Of The Time (< 1 Day)
# 3298       (1) Rarely/None Of The Time (< 1 Day)
# 3299       (1) Rarely/None Of The Time (< 1 Day)
# 3300       (1) Rarely/None Of The Time (< 1 Day)
# 3301         (4) Most/All Of The Time (5-7 Days)
# Name: GETGOIN0, Length: 3302, dtype: object
# 0       -1
# 1       -1
# 2       -1
# 3       -1
# 4       -1
#              ...
# 3297    -1
# 3298    -1
# 3299    -1
# 3300    -1
# 3301    -1
# Name: PROGSPE0, Length: 3302, dtype: object
# 0       (1) None Or Less Than 1 Hr/Wk
# 1       (1) None Or Less Than 1 Hr/Wk
# 2       (1) None Or Less Than 1 Hr/Wk
# 3       (1) None Or Less Than 1 Hr/Wk
# 4               (3) 20 Hrs Or More/Wk
#                     ...
# 3297            (3) 20 Hrs Or More/Wk
# 3298    (1) None Or Less Than 1 Hr/Wk
# 3299    (1) None Or Less Than 1 Hr/Wk
# 3300    (1) None Or Less Than 1 Hr/Wk
# 3301    (1) None Or Less Than 1 Hr/Wk
# Name: CHLDCAR0, Length: 3302, dtype: object
# 0       (2) Between 1 And 2 Hrs/Day
# 1           (3) More Than 2 Hrs/Day
# 2           (3) More Than 2 Hrs/Day
# 3        (1) 1 Hour Or Less Per Day
# 4       (2) Between 1 And 2 Hrs/Day
#                    ...
# 3297        (3) More Than 2 Hrs/Day
# 3298    (2) Between 1 And 2 Hrs/Day
# 3299     (1) 1 Hour Or Less Per Day
# 3300    (2) Between 1 And 2 Hrs/Day
# 3301        (3) More Than 2 Hrs/Day
# Name: PREPMEA0, Length: 3302, dtype: object
# 0                       (3) Daily Or More
# 1                       (3) Daily Or More
# 2                       (3) Daily Or More
# 3       (2) More Than Once/Wk But < Daily
# 4       (2) More Than Once/Wk But < Daily
#                       ...
# 3297                    (3) Daily Or More
# 3298                    (3) Daily Or More
# 3299    (2) More Than Once/Wk But < Daily
# 3300    (2) More Than Once/Wk But < Daily
# 3301    (2) More Than Once/Wk But < Daily
# Name: LGTCHOR0, Length: 3302, dtype: object
# 0       (3) 4 Or More Times/Month
# 1       (3) 4 Or More Times/Month
# 2             (2) 2-3 Times/Month
# 3             (2) 2-3 Times/Month
# 4       (3) 4 Or More Times/Month
#                   ...
# 3297          (2) 2-3 Times/Month
# 3298    (3) 4 Or More Times/Month
# 3299    (3) 4 Or More Times/Month
# 3300     (1) Once A Month Or Less
# 3301    (3) 4 Or More Times/Month
# Name: MODCHOR0, Length: 3302, dtype: object
# 0       (1) Once A Month Or Less
# 1       (1) Once A Month Or Less
# 2       (1) Once A Month Or Less
# 3       (1) Once A Month Or Less
# 4       (1) Once A Month Or Less
#                   ...
# 3297    (1) Once A Month Or Less
# 3298    (1) Once A Month Or Less
# 3299    (1) Once A Month Or Less
# 3300    (1) Once A Month Or Less
# 3301    (1) Once A Month Or Less
# Name: VIGCHOR0, Length: 3302, dtype: object
# 0                           (4) 2-4 Hrs/Day
# 1                           (4) 2-4 Hrs/Day
# 2                           (3) 1-2 Hrs/Day
# 3                           (4) 2-4 Hrs/Day
# 4       (2) At Least 1 Hr/Wk But < 1 Hr/Day
#                        ...
# 3297                (5) More Than 4 Hrs/Day
# 3298                (5) More Than 4 Hrs/Day
# 3299                        (4) 2-4 Hrs/Day
# 3300                        (4) 2-4 Hrs/Day
# 3301                        (3) 1-2 Hrs/Day
# Name: WATCHTV0, Length: 3302, dtype: object
# 0         (5) More Than 45 Minutes/Day
# 1       (1) Never/ < 5 Minutes Per Day
# 2                 (2) 5-15 Minutes/Day
# 3                (3) 16-30 Minutes/Day
# 4                (3) 16-30 Minutes/Day
#                      ...
# 3297    (1) Never/ < 5 Minutes Per Day
# 3298    (1) Never/ < 5 Minutes Per Day
# 3299    (1) Never/ < 5 Minutes Per Day
# 3300    (1) Never/ < 5 Minutes Per Day
# 3301              (2) 5-15 Minutes/Day
# Name: WALKBIK0, Length: 3302, dtype: object
# 0       (1) Never/Less Than Once A Month
# 1                            (4) Once/Wk
# 2       (1) Never/Less Than Once A Month
# 3                            (4) Once/Wk
# 4       (1) Never/Less Than Once A Month
#                       ...
# 3297                         (4) Once/Wk
# 3298               (3) 2-3 Times A Month
# 3299                    (2) Once A Month
# 3300    (1) Never/Less Than Once A Month
# 3301               (3) 2-3 Times A Month
# Name: SWEATPA0, Length: 3302, dtype: object
# 0               (4) Yes, 3-4 Times/Wk
# 1                (2) Yes, < Once A Wk
# 2               (3) Yes, 1-2 Times/Wk
# 3       (1) No, Not In The Past 2 Wks
# 4       (1) No, Not In The Past 2 Wks
#                     ...
# 3297             (2) Yes, < Once A Wk
# 3298    (1) No, Not In The Past 2 Wks
# 3299            (3) Yes, 1-2 Times/Wk
# 3300    (1) No, Not In The Past 2 Wks
# 3301            (4) Yes, 3-4 Times/Wk
# Name: TRBLSLE0, Length: 3302, dtype: object
# 0               (4) Yes, 3-4 Times/Wk
# 1         (5) Yes, 5 or More Times/Wk
# 2                (2) Yes, < Once A Wk
# 3                (2) Yes, < Once A Wk
# 4       (1) No, Not In The Past 2 Wks
#                     ...
# 3297            (4) Yes, 3-4 Times/Wk
# 3298             (2) Yes, < Once A Wk
# 3299    (1) No, Not In The Past 2 Wks
# 3300    (1) No, Not In The Past 2 Wks
# 3301            (4) Yes, 3-4 Times/Wk
# Name: WAKEUP0, Length: 3302, dtype: object
# 0         (5) Yes, 5 or More Times/Wk
# 1               (3) Yes, 1-2 Times/Wk
# 2                (2) Yes, < Once A Wk
# 3                (2) Yes, < Once A Wk
# 4       (1) No, Not In The Past 2 Wks
#                     ...
# 3297            (3) Yes, 1-2 Times/Wk
# 3298    (1) No, Not In The Past 2 Wks
# 3299    (1) No, Not In The Past 2 Wks
# 3300    (1) No, Not In The Past 2 Wks
# 3301            (3) Yes, 1-2 Times/Wk
# Name: WAKEARL0, Length: 3302, dtype: object
# 0                           (1) Never
# 1        (6) More Than Once Per Night
# 2            (2) Rarely (< Once A Wk)
# 3            (2) Rarely (< Once A Wk)
# 4       (5) Once A Night, Every Night
#                     ...
# 3297    (5) Once A Night, Every Night
# 3298    (5) Once A Night, Every Night
# 3299         (2) Rarely (< Once A Wk)
# 3300         (2) Rarely (< Once A Wk)
# 3301    (5) Once A Night, Every Night
# Name: GETUPUR0, Length: 3302, dtype: object
# 0         (4) Almost Daily/Daily
# 1                            NaN
# 2       (2) Less Than 1 Day/Week
# 3         (4) Almost Daily/Daily
# 4          (3) Several Days/Week
#                   ...
# 3297                         NaN
# 3298    (2) Less Than 1 Day/Week
# 3299                         NaN
# 3300                         NaN
# 3301      (4) Almost Daily/Daily
# Name: DAYSLEA0, Length: 3302, dtype: object
# 0       (2) Enough to Change Underwear/Wear Liner
# 1                                             NaN
# 2                               (1) A Drop Or Two
# 3       (2) Enough to Change Underwear/Wear Liner
# 4       (2) Enough to Change Underwear/Wear Liner
#                           ...
# 3297                                          NaN
# 3298             (3) Enough to Wet Outer Clothing
# 3299                                          NaN
# 3300                                          NaN
# 3301    (2) Enough to Change Underwear/Wear Liner
# Name: AMTLEAK0, Length: 3302, dtype: object
# 0       (16) Other, incl agnostic/atheist
# 1                       (05) Presbyterian
# 2                     (07) Roman Catholic
# 3                          (04) Episcopal
# 4       (16) Other, incl agnostic/atheist
#                       ...
# 3297                         (03) Baptist
# 3298                (06) Other Protestant
# 3299                (06) Other Protestant
# 3300                            (17) None
# 3301                  (07) Roman Catholic
# Name: RELIPRE0, Length: 3302, dtype: object
# 0       (6) Nearly every day - >=4 times/wk
# 1               (4) Monthly/Few Times a Mon
# 2                           (2) < Once a Yr
# 3       (5) At Least Once/Wk - 1-3 times/wk
# 4       (6) Nearly every day - >=4 times/wk
#                        ...
# 3297              (3) Yearly/Few Times a Yr
# 3298    (6) Nearly every day - >=4 times/wk
# 3299    (5) At Least Once/Wk - 1-3 times/wk
# 3300                              (1) Never
# 3301    (6) Nearly every day - >=4 times/wk
# Name: PRAY0, Length: 3302, dtype: object
# 0       (5) At Least Once/Wk - 1-3 times/wk
# 1                 (3) Yearly/Few Times a Yr
# 2                           (2) < Once a Yr
# 3                           (2) < Once a Yr
# 4               (4) Monthly/Few Times a Mon
#                        ...
# 3297              (3) Yearly/Few Times a Yr
# 3298                        (2) < Once a Yr
# 3299                        (2) < Once a Yr
# 3300                              (1) Never
# 3301            (4) Monthly/Few Times a Mon
# Name: RELISRV0, Length: 3302, dtype: object
# 0       (2) Once or Twice/Mon
# 1       (2) Once or Twice/Mon
# 2       (4) More than Once/Wk
# 3       (4) More than Once/Wk
# 4       (2) Once or Twice/Mon
#                 ...
# 3297        (3) About Once/Wk
# 3298    (4) More than Once/Wk
# 3299           (1) Not At All
# 3300    (2) Once or Twice/Mon
# 3301           (1) Not At All
# Name: DESIRSE0, Length: 3302, dtype: object
# 0                         NaN
# 1       (2) Once or Twice/Mon
# 2                   (5) Daily
# 3                   (5) Daily
# 4       (4) More than Once/Wk
#                 ...
# 3297    (4) More than Once/Wk
# 3298                (5) Daily
# 3299                      NaN
# 3300    (4) More than Once/Wk
# 3301                      NaN
# Name: KISSING0, Length: 3302, dtype: object
# 0                         NaN
# 1                   (5) Daily
# 2                   (5) Daily
# 3       (4) More than Once/Wk
# 4           (3) About Once/Wk
#                 ...
# 3297        (3) About Once/Wk
# 3298    (4) More than Once/Wk
# 3299                      NaN
# 3300    (4) More than Once/Wk
# 3301                      NaN
# Name: TOUCHIN0, Length: 3302, dtype: object
# 0                         NaN
# 1              (1) Not At All
# 2           (3) About Once/Wk
# 3       (2) Once or Twice/Mon
# 4       (2) Once or Twice/Mon
#                 ...
# 3297           (1) Not At All
# 3298        (3) About Once/Wk
# 3299                      NaN
# 3300    (2) Once or Twice/Mon
# 3301                      NaN
# Name: ORALSEX0, Length: 3302, dtype: object
# 0                         NaN
# 1       (2) Once or Twice/Mon
# 2       (4) More than Once/Wk
# 3           (3) About Once/Wk
# 4       (4) More than Once/Wk
#                 ...
# 3297        (3) About Once/Wk
# 3298        (3) About Once/Wk
# 3299                      NaN
# 3300    (2) Once or Twice/Mon
# 3301                      NaN
# Name: INTCOUR0, Length: 3302, dtype: object
# 0       (3) Once or Twice/Mon
# 1              (1) Not At All
# 2              (1) Not At All
# 3              (1) Not At All
# 4              (1) Not At All
#                 ...
# 3297           (1) Not At All
# 3298           (1) Not At All
# 3299           (1) Not At All
# 3300           (1) Not At All
# 3301           (1) Not At All
# Name: MASTURB0, Length: 3302, dtype: object
# 0       (3) Sex with a man
# 1       (3) Sex with a man
# 2       (3) Sex with a man
# 3       (3) Sex with a man
# 4       (3) Sex with a man
#                ...
# 3297    (3) Sex with a man
# 3298    (3) Sex with a man
# 3299     (1) Never had sex
# 3300    (3) Sex with a man
# 3301    (3) Sex with a man
# Name: WHOSEX0, Length: 3302, dtype: object
# 0           (2) 1-2/wk
# 1            (7) 2/day
# 2           (4) 5-6/wk
# 3            (7) 2/day
# 4           (4) 5-6/wk
#              ...
# 3297         (5) 1/day
# 3298        (4) 5-6/wk
# 3299         (7) 2/day
# 3300    (6) 1 1/2 /day
# 3301        (3) 3-4/wk
# Name: GLOBVEG0, Length: 3302, dtype: object
# 0        (5) 1/day
# 1        (5) 1/day
# 2        (5) 1/day
# 3        (7) 2/day
# 4       (2) 1-2/wk
#            ...
# 3297    (3) 3-4/wk
# 3298    (3) 3-4/wk
# 3299     (7) 2/day
# 3300    (4) 5-6/wk
# 3301    (2) 1-2/wk
# Name: GLOBFRT0, Length: 3302, dtype: object
# 0       (1) < 1/wk
# 1       (3) 3-4/wk
# 2       (3) 3-4/wk
# 3        (5) 1/day
# 4       (1) < 1/wk
#            ...
# 3297    (2) 1-2/wk
# 3298    (3) 3-4/wk
# 3299    (3) 3-4/wk
# 3300    (1) < 1/wk
# 3301    (1) < 1/wk
# Name: GLOBCER0, Length: 3302, dtype: object
# 0       (4) 5-6/wk
# 1        (5) 1/day
# 2       (2) 1-2/wk
# 3       (1) < 1/wk
# 4       (1) < 1/wk
#            ...
# 3297    (3) 3-4/wk
# 3298    (2) 1-2/wk
# 3299     (7) 2/day
# 3300    (1) < 1/wk
# 3301    (1) < 1/wk
# Name: GLOBMLK0, Length: 3302, dtype: object
# 0                (458) Hairdressers & cosmetologists
# 1                        (379) General office clerks
# 2                                                NaN
# 3           (033) Purchasing agents & buyers, n.e.c.
# 4                            (095) Registered nurses
#                             ...
# 3297                                             NaN
# 3298    (037) Management related occupations, n.e.c.
# 3299               (156) Teachers, elementary school
# 3300         (022) Managers & administrators, n.e.c.
# 3301                                             NaN
# Name: OCCUP0, Length: 3302, dtype: object
# 0                           (5) Hispanic
# 1           (2) Chinese/Chinese American
# 2       (4) Caucasian/White Non-Hispanic
# 3       (4) Caucasian/White Non-Hispanic
# 4             (1) Black/African American
#                       ...
# 3297          (1) Black/African American
# 3298      (3) Japanese/Japanese American
# 3299    (4) Caucasian/White Non-Hispanic
# 3300        (2) Chinese/Chinese American
# 3301                        (5) Hispanic
# Name: RACE, Length: 3302, dtype: object
# 0           (2) Chinese/Chinese American
# 1       (4) Caucasian/White Non-Hispanic
# 2       (4) Caucasian/White Non-Hispanic
# 3             (1) Black/African American
# 4         (3) Japanese/Japanese American
#                       ...
# 2876          (1) Black/African American
# 2877      (3) Japanese/Japanese American
# 2878    (4) Caucasian/White Non-Hispanic
# 2879        (2) Chinese/Chinese American
# 2880                        (5) Hispanic
# Name: RACE, Length: 2881, dtype: object
# 0       (1) Yes, as per protocol
# 1       (1) Yes, as per protocol
# 2       (1) Yes, as per protocol
# 3       (1) Yes, as per protocol
# 4       (1) Yes, as per protocol
#                   ...
# 2876    (1) Yes, as per protocol
# 2877    (1) Yes, as per protocol
# 2878    (1) Yes, as per protocol
# 2879    (1) Yes, as per protocol
# 2880    (1) Yes, as per protocol
# Name: BLDRWAT1, Length: 2881, dtype: object
# 0       (1) Do not take any
# 1       (1) Do not take any
# 2                       NaN
# 3         (3) 4-6 days/week
# 4                       NaN
#                ...
# 2876                    NaN
# 2877                    NaN
# 2878          (4) Every day
# 2879                    NaN
# 2880                    NaN
# Name: ONCEADA1, Length: 2881, dtype: object
# 0             (4) Every day
# 1       (1) Do not take any
# 2                       NaN
# 3       (1) Do not take any
# 4                       NaN
#                ...
# 2876                    NaN
# 2877                    NaN
# 2878    (1) Do not take any
# 2879                    NaN
# 2880                    NaN
# Name: ANTIOXI1, Length: 2881, dtype: object
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2876    NaN
# 2877    NaN
# 2878    NaN
# 2879    NaN
# 2880    NaN
# Name: VTMOTH11, Length: 2881, dtype: object
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2876    NaN
# 2877    NaN
# 2878    NaN
# 2879    NaN
# 2880    NaN
# Name: VTMOTH21, Length: 2881, dtype: object
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2876    NaN
# 2877    NaN
# 2878    NaN
# 2879    NaN
# 2880    NaN
# Name: VTMOTH31, Length: 2881, dtype: object
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2876    NaN
# 2877    NaN
# 2878    NaN
# 2879    NaN
# 2880    NaN
# Name: VTMOTH41, Length: 2881, dtype: object
# 0       (1) Do not take any
# 1         (2) 1-3 days/week
# 2                       NaN
# 3       (1) Do not take any
# 4                       NaN
#                ...
# 2876                    NaN
# 2877                    NaN
# 2878    (1) Do not take any
# 2879                    NaN
# 2880                    NaN
# Name: VITAMNA1, Length: 2881, dtype: object
# 0       (1) Do not take any
# 1       (1) Do not take any
# 2                       NaN
# 3       (1) Do not take any
# 4                       NaN
#                ...
# 2876                    NaN
# 2877                    NaN
# 2878    (1) Do not take any
# 2879                    NaN
# 2880                    NaN
# Name: BETACAR1, Length: 2881, dtype: object
# 0       (1) Do not take any
# 1             (4) Every day
# 2                       NaN
# 3       (1) Do not take any
# 4                       NaN
#                ...
# 2876                    NaN
# 2877                    NaN
# 2878    (1) Do not take any
# 2879                    NaN
# 2880                    NaN
# Name: VITAMNC1, Length: 2881, dtype: object
# 0       (1) Do not take any
# 1       (1) Do not take any
# 2                       NaN
# 3       (1) Do not take any
# 4                       NaN
#                ...
# 2876                    NaN
# 2877                    NaN
# 2878    (1) Do not take any
# 2879                    NaN
# 2880                    NaN
# Name: VITAMND1, Length: 2881, dtype: object
# 0             (4) Every day
# 1             (4) Every day
# 2                       NaN
# 3       (1) Do not take any
# 4                       NaN
#                ...
# 2876                    NaN
# 2877                    NaN
# 2878    (1) Do not take any
# 2879                    NaN
# 2880                    NaN
# Name: VITAMNE1, Length: 2881, dtype: object
# 0             (4) Every day
# 1             (4) Every day
# 2                       NaN
# 3       (1) Do not take any
# 4                       NaN
#                ...
# 2876                    NaN
# 2877                    NaN
# 2878    (1) Do not take any
# 2879                    NaN
# 2880                    NaN
# Name: CALCTUM1, Length: 2881, dtype: object
# 0       (1) Do not take any
# 1             (4) Every day
# 2                       NaN
# 3       (1) Do not take any
# 4                       NaN
#                ...
# 2876                    NaN
# 2877                    NaN
# 2878    (1) Do not take any
# 2879                    NaN
# 2880                    NaN
# Name: IRON1, Length: 2881, dtype: object
# 0                 NaN
# 1       (4) Every day
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 2876              NaN
# 2877              NaN
# 2878              NaN
# 2879              NaN
# 2880              NaN
# Name: VITOTH11, Length: 2881, dtype: object
# 0                 NaN
# 1       (4) Every day
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 2876              NaN
# 2877              NaN
# 2878              NaN
# 2879              NaN
# 2880              NaN
# Name: VITOTH21, Length: 2881, dtype: object
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2876    NaN
# 2877    NaN
# 2878    NaN
# 2879    NaN
# 2880    NaN
# Name: VITOTH31, Length: 2881, dtype: object
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2876    NaN
# 2877    NaN
# 2878    NaN
# 2879    NaN
# 2880    NaN
# Name: VITOTH41, Length: 2881, dtype: object
# 0       (1) Contains minerals (iron/calc)
# 1                                     NaN
# 2                                     NaN
# 3       (1) Contains minerals (iron/calc)
# 4                                     NaN
#                       ...
# 2876                                  NaN
# 2877                                  NaN
# 2878    (1) Contains minerals (iron/calc)
# 2879                                  NaN
# 2880                                  NaN
# Name: MULTVIT1, Length: 2881, dtype: object
# 0       -1
# 1       -1
# 2       "PINKY" FINGER BONE BROKE
# 3       -1
# 4       -1
#                      ...
# 2876    -1
# 2877    -1
# 2878    -1
# 2879    -1
# 2880    -1
# Name: BONES11, Length: 2881, dtype: object
# 0                   (1) Rarely/none of the time (< 1 day)
# 1       (3) Occasionally/moderate amount of the time (...
# 2                (2) Some/a little of the time (1-2 days)
# 3                (2) Some/a little of the time (1-2 days)
# 4                   (1) Rarely/none of the time (< 1 day)
#                               ...
# 2876             (2) Some/a little of the time (1-2 days)
# 2877                  (4) Most/all of the time (5-7 days)
# 2878                (1) Rarely/none of the time (< 1 day)
# 2879                (1) Rarely/none of the time (< 1 day)
# 2880             (2) Some/a little of the time (1-2 days)
# Name: BOTHER1, Length: 2881, dtype: object
# 0                   (1) Rarely/none of the time (< 1 day)
# 1                   (1) Rarely/none of the time (< 1 day)
# 2                   (1) Rarely/none of the time (< 1 day)
# 3                   (1) Rarely/none of the time (< 1 day)
# 4                   (1) Rarely/none of the time (< 1 day)
#                               ...
# 2876                (1) Rarely/none of the time (< 1 day)
# 2877    (3) Occasionally/moderate amount of the time (...
# 2878             (2) Some/a little of the time (1-2 days)
# 2879                (1) Rarely/none of the time (< 1 day)
# 2880                (1) Rarely/none of the time (< 1 day)
# Name: APPETIT1, Length: 2881, dtype: object
# 0                   (1) Rarely/none of the time (< 1 day)
# 1                   (1) Rarely/none of the time (< 1 day)
# 2                   (1) Rarely/none of the time (< 1 day)
# 3                   (1) Rarely/none of the time (< 1 day)
# 4                   (1) Rarely/none of the time (< 1 day)
#                               ...
# 2876             (2) Some/a little of the time (1-2 days)
# 2877    (3) Occasionally/moderate amount of the time (...
# 2878                (1) Rarely/none of the time (< 1 day)
# 2879                (1) Rarely/none of the time (< 1 day)
# 2880                (1) Rarely/none of the time (< 1 day)
# Name: BLUES1, Length: 2881, dtype: object
# 0                     (4) Most/all of the time (5-7 days)
# 1                     (4) Most/all of the time (5-7 days)
# 2       (3) Occasionally/moderate amount of the time (...
# 3                     (4) Most/all of the time (5-7 days)
# 4                     (4) Most/all of the time (5-7 days)
#                               ...
# 2876    (3) Occasionally/moderate amount of the time (...
# 2877                  (4) Most/all of the time (5-7 days)
# 2878                  (4) Most/all of the time (5-7 days)
# 2879                  (4) Most/all of the time (5-7 days)
# 2880                  (4) Most/all of the time (5-7 days)
# Name: GOOD1, Length: 2881, dtype: object
# 0                   (1) Rarely/none of the time (< 1 day)
# 1                   (1) Rarely/none of the time (< 1 day)
# 2                (2) Some/a little of the time (1-2 days)
# 3       (3) Occasionally/moderate amount of the time (...
# 4                   (1) Rarely/none of the time (< 1 day)
#                               ...
# 2876    (3) Occasionally/moderate amount of the time (...
# 2877                  (4) Most/all of the time (5-7 days)
# 2878                (1) Rarely/none of the time (< 1 day)
# 2879                (1) Rarely/none of the time (< 1 day)
# 2880             (2) Some/a little of the time (1-2 days)
# Name: KEEPMIN1, Length: 2881, dtype: object
# 0                   (1) Rarely/none of the time (< 1 day)
# 1                   (1) Rarely/none of the time (< 1 day)
# 2                   (1) Rarely/none of the time (< 1 day)
# 3                (2) Some/a little of the time (1-2 days)
# 4                   (1) Rarely/none of the time (< 1 day)
#                               ...
# 2876    (3) Occasionally/moderate amount of the time (...
# 2877                  (4) Most/all of the time (5-7 days)
# 2878             (2) Some/a little of the time (1-2 days)
# 2879             (2) Some/a little of the time (1-2 days)
# 2880             (2) Some/a little of the time (1-2 days)
# Name: DEPRESS1, Length: 2881, dtype: object
# 0                   (1) Rarely/none of the time (< 1 day)
# 1                (2) Some/a little of the time (1-2 days)
# 2                   (1) Rarely/none of the time (< 1 day)
# 3                   (1) Rarely/none of the time (< 1 day)
# 4                   (1) Rarely/none of the time (< 1 day)
#                               ...
# 2876    (3) Occasionally/moderate amount of the time (...
# 2877                  (4) Most/all of the time (5-7 days)
# 2878                (1) Rarely/none of the time (< 1 day)
# 2879                (1) Rarely/none of the time (< 1 day)
# 2880             (2) Some/a little of the time (1-2 days)
# Name: EFFORT1, Length: 2881, dtype: object
# 0                     (4) Most/all of the time (5-7 days)
# 1                     (4) Most/all of the time (5-7 days)
# 2       (3) Occasionally/moderate amount of the time (...
# 3                     (4) Most/all of the time (5-7 days)
# 4                     (4) Most/all of the time (5-7 days)
#                               ...
# 2876             (2) Some/a little of the time (1-2 days)
# 2877             (2) Some/a little of the time (1-2 days)
# 2878    (3) Occasionally/moderate amount of the time (...
# 2879                  (4) Most/all of the time (5-7 days)
# 2880             (2) Some/a little of the time (1-2 days)
# Name: HOPEFUL1, Length: 2881, dtype: object
# 0                   (1) Rarely/none of the time (< 1 day)
# 1                   (1) Rarely/none of the time (< 1 day)
# 2                   (1) Rarely/none of the time (< 1 day)
# 3                   (1) Rarely/none of the time (< 1 day)
# 4                   (1) Rarely/none of the time (< 1 day)
#                               ...
# 2876             (2) Some/a little of the time (1-2 days)
# 2877    (3) Occasionally/moderate amount of the time (...
# 2878                (1) Rarely/none of the time (< 1 day)
# 2879                (1) Rarely/none of the time (< 1 day)
# 2880                (1) Rarely/none of the time (< 1 day)
# Name: FAILURE1, Length: 2881, dtype: object
# 0          (1) Rarely/none of the time (< 1 day)
# 1          (1) Rarely/none of the time (< 1 day)
# 2          (1) Rarely/none of the time (< 1 day)
# 3          (1) Rarely/none of the time (< 1 day)
# 4          (1) Rarely/none of the time (< 1 day)
#                           ...
# 2876       (1) Rarely/none of the time (< 1 day)
# 2877         (4) Most/all of the time (5-7 days)
# 2878    (2) Some/a little of the time (1-2 days)
# 2879       (1) Rarely/none of the time (< 1 day)
# 2880       (1) Rarely/none of the time (< 1 day)
# Name: FEARFUL1, Length: 2881, dtype: object
# 0            (4) Most/all of the time (5-7 days)
# 1       (2) Some/a little of the time (1-2 days)
# 2          (1) Rarely/none of the time (< 1 day)
# 3          (1) Rarely/none of the time (< 1 day)
# 4          (1) Rarely/none of the time (< 1 day)
#                           ...
# 2876    (2) Some/a little of the time (1-2 days)
# 2877         (4) Most/all of the time (5-7 days)
# 2878    (2) Some/a little of the time (1-2 days)
# 2879    (2) Some/a little of the time (1-2 days)
# 2880    (2) Some/a little of the time (1-2 days)
# Name: RESTLES1, Length: 2881, dtype: object
# 0                     (4) Most/all of the time (5-7 days)
# 1                (2) Some/a little of the time (1-2 days)
# 2       (3) Occasionally/moderate amount of the time (...
# 3                   (1) Rarely/none of the time (< 1 day)
# 4                     (4) Most/all of the time (5-7 days)
#                               ...
# 2876                  (4) Most/all of the time (5-7 days)
# 2877    (3) Occasionally/moderate amount of the time (...
# 2878    (3) Occasionally/moderate amount of the time (...
# 2879                  (4) Most/all of the time (5-7 days)
# 2880             (2) Some/a little of the time (1-2 days)
# Name: HAPPY1, Length: 2881, dtype: object
# 0       (3) Occasionally/moderate amount of the time (...
# 1                   (1) Rarely/none of the time (< 1 day)
# 2                   (1) Rarely/none of the time (< 1 day)
# 3                   (1) Rarely/none of the time (< 1 day)
# 4                   (1) Rarely/none of the time (< 1 day)
#                               ...
# 2876             (2) Some/a little of the time (1-2 days)
# 2877    (3) Occasionally/moderate amount of the time (...
# 2878             (2) Some/a little of the time (1-2 days)
# 2879                (1) Rarely/none of the time (< 1 day)
# 2880                (1) Rarely/none of the time (< 1 day)
# Name: TALKLES1, Length: 2881, dtype: object
# 0                   (1) Rarely/none of the time (< 1 day)
# 1                   (1) Rarely/none of the time (< 1 day)
# 2                   (1) Rarely/none of the time (< 1 day)
# 3                   (1) Rarely/none of the time (< 1 day)
# 4                   (1) Rarely/none of the time (< 1 day)
#                               ...
# 2876             (2) Some/a little of the time (1-2 days)
# 2877    (3) Occasionally/moderate amount of the time (...
# 2878             (2) Some/a little of the time (1-2 days)
# 2879             (2) Some/a little of the time (1-2 days)
# 2880                (1) Rarely/none of the time (< 1 day)
# Name: LONELY1, Length: 2881, dtype: object
# 0          (1) Rarely/none of the time (< 1 day)
# 1          (1) Rarely/none of the time (< 1 day)
# 2          (1) Rarely/none of the time (< 1 day)
# 3          (1) Rarely/none of the time (< 1 day)
# 4          (1) Rarely/none of the time (< 1 day)
#                           ...
# 2876       (1) Rarely/none of the time (< 1 day)
# 2877       (1) Rarely/none of the time (< 1 day)
# 2878       (1) Rarely/none of the time (< 1 day)
# 2879    (2) Some/a little of the time (1-2 days)
# 2880    (2) Some/a little of the time (1-2 days)
# Name: UNFRNDL1, Length: 2881, dtype: object
# 0                     (4) Most/all of the time (5-7 days)
# 1                     (4) Most/all of the time (5-7 days)
# 2       (3) Occasionally/moderate amount of the time (...
# 3                (2) Some/a little of the time (1-2 days)
# 4                     (4) Most/all of the time (5-7 days)
#                               ...
# 2876             (2) Some/a little of the time (1-2 days)
# 2877    (3) Occasionally/moderate amount of the time (...
# 2878    (3) Occasionally/moderate amount of the time (...
# 2879                  (4) Most/all of the time (5-7 days)
# 2880             (2) Some/a little of the time (1-2 days)
# Name: ENJOY1, Length: 2881, dtype: object
# 0          (1) Rarely/none of the time (< 1 day)
# 1          (1) Rarely/none of the time (< 1 day)
# 2       (2) Some/a little of the time (1-2 days)
# 3          (1) Rarely/none of the time (< 1 day)
# 4          (1) Rarely/none of the time (< 1 day)
#                           ...
# 2876       (1) Rarely/none of the time (< 1 day)
# 2877         (4) Most/all of the time (5-7 days)
# 2878    (2) Some/a little of the time (1-2 days)
# 2879       (1) Rarely/none of the time (< 1 day)
# 2880       (1) Rarely/none of the time (< 1 day)
# Name: CRYING1, Length: 2881, dtype: object
# 0          (1) Rarely/none of the time (< 1 day)
# 1       (2) Some/a little of the time (1-2 days)
# 2       (2) Some/a little of the time (1-2 days)
# 3          (1) Rarely/none of the time (< 1 day)
# 4          (1) Rarely/none of the time (< 1 day)
#                           ...
# 2876       (1) Rarely/none of the time (< 1 day)
# 2877         (4) Most/all of the time (5-7 days)
# 2878    (2) Some/a little of the time (1-2 days)
# 2879       (1) Rarely/none of the time (< 1 day)
# 2880    (2) Some/a little of the time (1-2 days)
# Name: SAD1, Length: 2881, dtype: object
# 0          (1) Rarely/none of the time (< 1 day)
# 1          (1) Rarely/none of the time (< 1 day)
# 2          (1) Rarely/none of the time (< 1 day)
# 3          (1) Rarely/none of the time (< 1 day)
# 4       (2) Some/a little of the time (1-2 days)
#                           ...
# 2876       (1) Rarely/none of the time (< 1 day)
# 2877       (1) Rarely/none of the time (< 1 day)
# 2878       (1) Rarely/none of the time (< 1 day)
# 2879       (1) Rarely/none of the time (< 1 day)
# 2880       (1) Rarely/none of the time (< 1 day)
# Name: DISLIKE1, Length: 2881, dtype: object
# 0                   (1) Rarely/none of the time (< 1 day)
# 1                (2) Some/a little of the time (1-2 days)
# 2                (2) Some/a little of the time (1-2 days)
# 3                   (1) Rarely/none of the time (< 1 day)
# 4                   (1) Rarely/none of the time (< 1 day)
#                               ...
# 2876                (1) Rarely/none of the time (< 1 day)
# 2877    (3) Occasionally/moderate amount of the time (...
# 2878                (1) Rarely/none of the time (< 1 day)
# 2879                (1) Rarely/none of the time (< 1 day)
# 2880             (2) Some/a little of the time (1-2 days)
# Name: GETGOIN1, Length: 2881, dtype: object
# 0       (2) Currently married/living as married
# 1       (2) Currently married/living as married
# 2       (2) Currently married/living as married
# 3       (2) Currently married/living as married
# 4       (2) Currently married/living as married
#                          ...
# 2876                              (3) Separated
# 2877    (2) Currently married/living as married
# 2878                   (1) Single/never married
# 2879    (2) Currently married/living as married
# 2880    (2) Currently married/living as married
# Name: MARITAL1, Length: 2881, dtype: object
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#                       ...
# 2876                                  NaN
# 2877                                  NaN
# 2878                                  NaN
# 2879    (3) Infrequently (several x/year)
# 2880             (5) Rarely (< once/year)
# Name: CONTCT11, Length: 2881, dtype: object
# 0             (7) Have not moved
# 1                      (6) Never
# 2       (5) Rarely (< once/year)
# 3                      (6) Never
# 4                     (4) Yearly
#                   ...
# 2876          (7) Have not moved
# 2877                  (1) Weekly
# 2878          (7) Have not moved
# 2879                         NaN
# 2880                         NaN
# Name: CONTCT21, Length: 2881, dtype: object
# 0       (4) Infrequently(several x/year)
# 1                              (1) Daily
# 2                              (1) Daily
# 3                              (1) Daily
# 4                              (1) Daily
#                       ...
# 2876                           (1) Daily
# 2877                           (1) Daily
# 2878                           (1) Daily
# 2879                           (1) Daily
# 2880                           (1) Daily
# Name: CONTETH1, Length: 2881, dtype: object
# 0       -1
# 1       -1
# ...
# 2743       (1) Rarely/none of the time (< 1 day)
# 2744       (1) Rarely/none of the time (< 1 day)
# 2745    (2) Some/a little of the time (1-2 days)
# 2746       (1) Rarely/none of the time (< 1 day)
# 2747    (2) Some/a little of the time (1-2 days)
# Name: RESTLES2, Length: 2748, dtype: object
# 0                   (4) Most/all of the time (5-7 days)
# 1                   (4) Most/all of the time (5-7 days)
# 2       (3) Occasionally/mod amt of the time (3-4 days)
# 3                   (4) Most/all of the time (5-7 days)
# 4                   (4) Most/all of the time (5-7 days)
#                              ...
# 2743           (2) Some/a little of the time (1-2 days)
# 2744                (4) Most/all of the time (5-7 days)
# 2745           (2) Some/a little of the time (1-2 days)
# 2746                (4) Most/all of the time (5-7 days)
# 2747           (2) Some/a little of the time (1-2 days)
# Name: HAPPY2, Length: 2748, dtype: object
# 0              (2) Some/a little of the time (1-2 days)
# 1                 (1) Rarely/none of the time (< 1 day)
# 2       (3) Occasionally/mod amt of the time (3-4 days)
# 3                 (1) Rarely/none of the time (< 1 day)
# 4                 (1) Rarely/none of the time (< 1 day)
#                              ...
# 2743           (2) Some/a little of the time (1-2 days)
# 2744              (1) Rarely/none of the time (< 1 day)
# 2745           (2) Some/a little of the time (1-2 days)
# 2746              (1) Rarely/none of the time (< 1 day)
# 2747              (1) Rarely/none of the time (< 1 day)
# Name: TALKLES2, Length: 2748, dtype: object
# 0                 (1) Rarely/none of the time (< 1 day)
# 1                 (1) Rarely/none of the time (< 1 day)
# 2       (3) Occasionally/mod amt of the time (3-4 days)
# 3                 (1) Rarely/none of the time (< 1 day)
# 4                 (1) Rarely/none of the time (< 1 day)
#                              ...
# 2743           (2) Some/a little of the time (1-2 days)
# 2744              (1) Rarely/none of the time (< 1 day)
# 2745           (2) Some/a little of the time (1-2 days)
# 2746              (1) Rarely/none of the time (< 1 day)
# 2747              (1) Rarely/none of the time (< 1 day)
# Name: LONELY2, Length: 2748, dtype: object
# 0       (1) Rarely/none of the time (< 1 day)
# 1       (1) Rarely/none of the time (< 1 day)
# 2       (1) Rarely/none of the time (< 1 day)
# 3       (1) Rarely/none of the time (< 1 day)
# 4       (1) Rarely/none of the time (< 1 day)
#                         ...
# 2743    (1) Rarely/none of the time (< 1 day)
# 2744    (1) Rarely/none of the time (< 1 day)
# 2745    (1) Rarely/none of the time (< 1 day)
# 2746    (1) Rarely/none of the time (< 1 day)
# 2747    (1) Rarely/none of the time (< 1 day)
# Name: UNFRNDL2, Length: 2748, dtype: object
# 0                   (4) Most/all of the time (5-7 days)
# 1                   (4) Most/all of the time (5-7 days)
# 2       (3) Occasionally/mod amt of the time (3-4 days)
# 3                   (4) Most/all of the time (5-7 days)
# 4                   (4) Most/all of the time (5-7 days)
#                              ...
# 2743    (3) Occasionally/mod amt of the time (3-4 days)
# 2744                (4) Most/all of the time (5-7 days)
# 2745           (2) Some/a little of the time (1-2 days)
# 2746                (4) Most/all of the time (5-7 days)
# 2747           (2) Some/a little of the time (1-2 days)
# Name: ENJOY2, Length: 2748, dtype: object
# 0                 (1) Rarely/none of the time (< 1 day)
# 1                 (1) Rarely/none of the time (< 1 day)
# 2       (3) Occasionally/mod amt of the time (3-4 days)
# 3                 (1) Rarely/none of the time (< 1 day)
# 4                 (1) Rarely/none of the time (< 1 day)
#                              ...
# 2743           (2) Some/a little of the time (1-2 days)
# 2744              (1) Rarely/none of the time (< 1 day)
# 2745           (2) Some/a little of the time (1-2 days)
# 2746              (1) Rarely/none of the time (< 1 day)
# 2747           (2) Some/a little of the time (1-2 days)
# Name: CRYING2, Length: 2748, dtype: object
# 0                 (1) Rarely/none of the time (< 1 day)
# 1                 (1) Rarely/none of the time (< 1 day)
# 2       (3) Occasionally/mod amt of the time (3-4 days)
# 3                 (1) Rarely/none of the time (< 1 day)
# 4                 (1) Rarely/none of the time (< 1 day)
#                              ...
# 2743    (3) Occasionally/mod amt of the time (3-4 days)
# 2744              (1) Rarely/none of the time (< 1 day)
# 2745           (2) Some/a little of the time (1-2 days)
# 2746              (1) Rarely/none of the time (< 1 day)
# 2747           (2) Some/a little of the time (1-2 days)
# Name: SAD2, Length: 2748, dtype: object
# 0       (1) Rarely/none of the time (< 1 day)
# 1       (1) Rarely/none of the time (< 1 day)
# 2       (1) Rarely/none of the time (< 1 day)
# 3       (1) Rarely/none of the time (< 1 day)
# 4       (1) Rarely/none of the time (< 1 day)
#                         ...
# 2743    (1) Rarely/none of the time (< 1 day)
# 2744    (1) Rarely/none of the time (< 1 day)
# 2745    (1) Rarely/none of the time (< 1 day)
# 2746    (1) Rarely/none of the time (< 1 day)
# 2747    (1) Rarely/none of the time (< 1 day)
# Name: DISLIKE2, Length: 2748, dtype: object
# 0          (1) Rarely/none of the time (< 1 day)
# 1       (2) Some/a little of the time (1-2 days)
# 2       (2) Some/a little of the time (1-2 days)
# 3          (1) Rarely/none of the time (< 1 day)
# 4          (1) Rarely/none of the time (< 1 day)
#                           ...
# 2743    (2) Some/a little of the time (1-2 days)
# 2744       (1) Rarely/none of the time (< 1 day)
# 2745       (1) Rarely/none of the time (< 1 day)
# 2746       (1) Rarely/none of the time (< 1 day)
# 2747       (1) Rarely/none of the time (< 1 day)
# Name: GETGOIN2, Length: 2748, dtype: object
# 0       (2) Currently married/living as married
# 1       (2) Currently married/living as married
# 2       (2) Currently married/living as married
# 3       (2) Currently married/living as married
# 4       (2) Currently married/living as married
#                          ...
# 2743    (2) Currently married/living as married
# 2744    (2) Currently married/living as married
# 2745                   (1) Single/never married
# 2746    (2) Currently married/living as married
# 2747    (2) Currently married/living as married
# Name: MARITAL2, Length: 2748, dtype: object
# 0       HUSBAND
# 1       HUSBAND
# 2       HUSBAND
# 3       HUSBAND
# 4       HUSBAND
#                     ...
# 2743    HUSBAND
# 2744    DAUGHTER
# 2745
# 2746    HUSBAND
# 2747    HUSBAND
# Name: RELAT12, Length: 2748, dtype: object
# 0       (7) Unknown due to HT use
# 1                  (4) Early peri
# 2                  (4) Early peri
# 3                   (3) Late peri
# 4                  (4) Early peri
#                   ...
# 2743    (7) Unknown due to HT use
# 2744               (4) Early peri
# 2745               (4) Early peri
# 2746               (4) Early peri
# 2747               (4) Early peri
# Name: STATUS2, Length: 2748, dtype: object
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 2743    NaN
# 2744    NaN
# 2745    NaN
# 2746    NaN
# 2747    NaN
# Name: PRIMREA2, Length: 2748, dtype: object
# 0                      NaN
# 1               (2) 1-3/mo
# 2                      NaN
# 3                      NaN
# 4                      NaN
#                ...
# 2743    (1) None or < 1/mo
# 2744                   NaN
# 2745    (1) None or < 1/mo
# 2746    (1) None or < 1/mo
# 2747    (1) None or < 1/mo
# Name: GLASBEE2, Length: 2748, dtype: object
# 0                      NaN
# 1               (5) 5-6/wk
# 2                      NaN
# 3                      NaN
# 4                      NaN
#                ...
# 2743            (2) 1-3/mo
# 2744                   NaN
# 2745            (4) 2-4/wk
# 2746    (1) None or < 1/mo
# 2747    (1) None or < 1/mo
# Name: GLASWIN2, Length: 2748, dtype: object
# 0                      NaN
# 1               (2) 1-3/mo
# 2                      NaN
# 3                      NaN
# 4                      NaN
#                ...
# 2743    (1) None or < 1/mo
# 2744                   NaN
# 2745    (1) None or < 1/mo
# 2746    (1) None or < 1/mo
# 2747    (1) None or < 1/mo
# Name: GLASLIQ2, Length: 2748, dtype: object
# 0                      (4) 2-4 hrs/day
# 1                      (3) 1-2 hrs/day
# 2                      (3) 1-2 hrs/day
# 3              (5) More than 4 hrs/day
# 4       (1) Never or less than 1 hr/wk
#                      ...
# 2743    (1) Never or less than 1 hr/wk
# 2744                   (4) 2-4 hrs/day
# 2745                   (3) 1-2 hrs/day
# 2746                   (3) 1-2 hrs/day
# 2747                   (4) 2-4 hrs/day
# Name: WATCHTV2, Length: 2748, dtype: object
# 0       (1) Never/ < 5 minutes per day
# 1         (5) More than 45 minutes/day
# 2                 (2) 5-15 minutes/day
# 3         (5) More than 45 minutes/day
# 4       (1) Never/ < 5 minutes per day
#                      ...
# 2743              (2) 5-15 minutes/day
# 2744    (1) Never/ < 5 minutes per day
# 2745    (1) Never/ < 5 minutes per day
# 2746             (3) 16-30 minutes/day
# 2747             (3) 16-30 minutes/day
# Name: WALKBIK2, Length: 2748, dtype: object
# 0                  (3) 2-3 times a month
# 1       (1) Never/less than once a month
# 2                       (2) Once a month
# 3                  (5) More than once/wk
# 4       (1) Never/less than once a month
#                       ...
# 2743               (5) More than once/wk
# 2744    (1) Never/less than once a month
# 2745               (5) More than once/wk
# 2746    (1) Never/less than once a month
# 2747    (1) Never/less than once a month
# Name: SWEATPA2, Length: 2748, dtype: object
# 0       (1) Never/less than once a month
# 1                  (5) More than once/wk
# 2       (1) Never/less than once a month
# 3                  (5) More than once/wk
# 4                         (2) Once/month
#                       ...
# 2743               (5) More than once/wk
# 2744               (5) More than once/wk
# 2745               (5) More than once/wk
# 2746               (5) More than once/wk
# 2747    (1) Never/less than once a month
# Name: SPORTS2, Length: 2748, dtype: object
# 0               (4) Yes, 3-4 times/wk
# 1               (3) Yes, 1-2 times/wk
# 2       (1) No, not in the past 2 wks
# 3       (1) No, not in the past 2 wks
# 4       (1) No, not in the past 2 wks
#                     ...
# 2743    (1) No, not in the past 2 wks
# 2744    (1) No, not in the past 2 wks
# 2745             (2) Yes, < once a wk
# 2746    (1) No, not in the past 2 wks
# 2747             (2) Yes, < once a wk
# Name: TRBLSLE2, Length: 2748, dtype: object
# 0         (5) Yes, 5 or more times/wk
# 1               (3) Yes, 1-2 times/wk
# 2               (4) Yes, 3-4 times/wk
# 3               (3) Yes, 1-2 times/wk
# 4       (1) No, not in the past 2 wks
#                     ...
# 2743    (1) No, not in the past 2 wks
# 2744            (3) Yes, 1-2 times/wk
# 2745            (3) Yes, 1-2 times/wk
# 2746    (1) No, not in the past 2 wks
# 2747            (3) Yes, 1-2 times/wk
# Name: WAKEUP2, Length: 2748, dtype: object
# 0         (5) Yes, 5 or more times/wk
# 1                (2) Yes, < once a wk
# 2                (2) Yes, < once a wk
# 3                (2) Yes, < once a wk
# 4       (1) No, not in the past 2 wks
#                     ...
# 2743    (1) No, not in the past 2 wks
# 2744             (2) Yes, < once a wk
# 2745            (3) Yes, 1-2 times/wk
# 2746             (2) Yes, < once a wk
# 2747            (3) Yes, 1-2 times/wk
# Name: WAKEARL2, Length: 2748, dtype: object
# 0       (5) Once a night, every night
# 1            (2) Rarely (< once a wk)
# 2       (5) Once a night, every night
# 3       (5) Once a night, every night
# 4                           (1) Never
#                     ...
# 2743         (2) Rarely (< once a wk)
# 2744    (5) Once a night, every night
# 2745               (4) A few times/wk
# 2746         (2) Rarely (< once a wk)
# 2747         (2) Rarely (< once a wk)
# Name: GETUPUR2, Length: 2748, dtype: object
# 0                            NaN
# 1          (3) Several days/week
# 2       (2) Less than 1 day/week
# 3          (3) Several days/week
# 4                      (1) Never
#                   ...
# 2743                   (1) Never
# 2744      (4) Almost daily/daily
# 2745                         NaN
# 2746                         NaN
# 2747                         NaN
# Name: DAYSLEA2, Length: 2748, dtype: object
# 0                                             NaN
# 1       (2) Enough to change underwear/wear liner
# 2       (2) Enough to change underwear/wear liner
# 3       (2) Enough to change underwear/wear liner
# 4                               (1) A drop or two
#                           ...
# 2743                            (1) A drop or two
# 2744    (2) Enough to change underwear/wear liner
# 2745                                          NaN
# 2746                                          NaN
# 2747                                          NaN
# Name: AMTLEAK2, Length: 2748, dtype: object
# 0       (2) Once or twice/mon
# 1       (4) More than once/wk
# 2       (2) Once or twice/mon
# 3              (1) Not at all
# 4       (2) Once or twice/mon
#                 ...
# 2743    (4) More than once/wk
# 2744    (4) More than once/wk
# 2745           (1) Not at all
# 2746    (2) Once or twice/mon
# 2747        (3) About once/wk
# Name: DESIRSE2, Length: 2748, dtype: object
# 0                   (5) Daily
# 1                   (5) Daily
# 2                   (5) Daily
# 3                         NaN
# 4                   (5) Daily
#                 ...
# 2743    (4) More than once/wk
# 2744                (5) Daily
# 2745                      NaN
# 2746    (2) Once or twice/mon
# 2747                      NaN
# Name: KISSING2, Length: 2748, dtype: object
# 0       (4) More than once/wk
# 1                   (5) Daily
# 2                   (5) Daily
# 3                         NaN
# 4       (2) Once or twice/mon
#                 ...
# 2743    (4) More than once/wk
# 2744    (4) More than once/wk
# 2745                      NaN
# 2746    (2) Once or twice/mon
# 2747                      NaN
# Name: TOUCHIN2, Length: 2748, dtype: object
# 0              (1) Not at all
# 1       (2) Once or twice/mon
# 2              (1) Not at all
# 3                         NaN
# 4              (1) Not at all
#                 ...
# 2743    (4) More than once/wk
# 2744        (3) About once/wk
# 2745                      NaN
# 2746    (2) Once or twice/mon
# 2747                      NaN
# Name: ORALSEX2, Length: 2748, dtype: object
# 0       (2) Once or twice/mon
# 1       (4) More than once/wk
# 2       (4) More than once/wk
# 3                         NaN
# 4       (2) Once or twice/mon
#                 ...
# 2743    (4) More than once/wk
# 2744    (4) More than once/wk
# 2745                      NaN
# 2746    (2) Once or twice/mon
# 2747                      NaN
# Name: INTCOUR2, Length: 2748, dtype: object
# 0               (1) Not at all
# 1               (1) Not at all
# 2               (1) Not at all
# 3               (1) Not at all
# 4               (1) Not at all
#                  ...
# 2743            (1) Not at all
# 2744            (1) Not at all
# 2745            (1) Not at all
# 2746    (2) Less Than once/mon
# 2747     (3) Once or twice/mon
# Name: MASTURB2, Length: 2748, dtype: object
# 0              (3) Gynecologist
# 1              (3) Gynecologist
# 2              (3) Gynecologist
# 3                 (2) Internist
# 4       (1) Family practitioner
#                  ...
# 2743           (3) Gynecologist
# 2744    (1) Family practitioner
# 2745    (1) Family practitioner
# 2746                        NaN
# 2747              (2) Internist
# Name: SPECIAL2, Length: 2748, dtype: object

# %% [markdown]
# Any times wih ':' - yes! Let's convert them for downstream consumption

# %%
for name,df in dfs.items():
    for col in df.columns:
        if df[col].dtype == 'object':
            if df[col].str.contains(':').any():
                print(f'{name},{col}, {df[col].unique()[:10]}')
# Out:
# baseline_df,SPSCTIM0, ['           .' '     0:09:03' '     0:15:07' '     0:18:29'
#  '     0:13:51' '     0:09:08' '     0:10:31' '     0:09:31'
#  '     0:11:10' '     0:10:02']
# baseline_df,HPSCTIM0, ['           .' '     0:08:53' '     0:15:17' '     0:18:13'
#  '     0:14:01' '     0:09:17' '     0:10:41' '     0:09:35'
#  '     0:10:56' '     0:10:08']
# baseline_df,HPSCMOD0, [nan '(05) 5: 2000 machine' '(11) 11: 4500 machine']
# visit1_df,STRTIM11, ['           .' '     9:00:00' '     8:00:00' '     8:30:00'
#  '     7:00:00' '    17:00:00' '     7:30:00' '     6:00:00'
#  '     9:30:00' '     8:15:00']
# visit1_df,STPTIM11, ['           .' '    17:00:00' '    15:00:00' '    15:15:00'
#  '    14:00:00' '    11:30:00' '     1:30:00' '    17:30:00'
#  '    16:00:00' '    14:30:00']
# visit1_df,SPSCTIM1, ['     0:10:08' '     0:12:55' '     0:18:01' '           .'
#  '     0:10:47' '     0:11:36' '     0:10:03' '     0:12:44'
#  '     0:12:59' '     0:16:12']
# visit1_df,HPSCTIM1, ['     0:09:52' '     0:13:03' '     0:17:39' '           .'
#  '     0:10:40' '     0:11:25' '     0:10:09' '     0:12:37'
#  '     0:12:45' '     0:16:03']
# visit2_df,STRTIM12, ['    10:00:00' '           .' '     8:00:00' '     8:30:00'
#  '     7:00:00' '     6:30:00' '     9:00:00' '     9:30:00'
#  '     6:00:00' '    23:00:00']
# visit2_df,STPTIM12, ['    21:00:00' '           .' '    17:00:00' '    15:30:00'
#  '    16:10:00' '    18:30:00' '    16:30:00' '    14:30:00'
#  '    16:00:00' '    21:30:00']
# visit2_df,STRTIM22, ['           .' '     8:30:00' '     8:00:00' '     9:00:00'
#  '    14:00:00' '     1:00:00' '    17:30:00' '    18:00:00'
#  '    13:00:00' '    10:00:00']
# visit2_df,STPTIM22, ['           .' '    15:30:00' '    17:30:00' '    14:00:00'
#  '    17:00:00' '    18:00:00' '    20:00:00' '    19:00:00'
#  '    20:30:00' '    18:30:00']
# visit2_df,STRTIM32, ['           .' '     8:30:00' '    21:00:00' '     8:15:00'
#  '    18:00:00' '    15:00:00' '     9:00:00' '    14:00:00'
#  '    17:30:00' '    18:30:00']
# visit2_df,STPTIM32, ['           .' '     9:30:00' '     1:00:00' '    14:34:59'
#  '    21:00:00' '    17:00:00' '    22:30:00' '    18:00:00'
#  '     6:30:00' '    22:00:00']
# visit2_df,SPSCTIM2, ['     0:10:07' '     0:14:05' '           .' '     0:11:09'
#  '     0:09:26' '     0:08:05' '     0:10:39' '     0:10:54'
#  '     0:10:55' '     0:09:16']

# %%
def _convert_dt(df_name,col,dict_of_dfs,_format):
    dict_of_dfs[df_name][col] = pd.to_datetime(dict_of_dfs[df_name][col],format = _format)
    
def mutate_dfs_convert_dts(dict_of_dfs):
    format_1_cols = [
    ('visit1_df','STRTIM11'),
    ('visit1_df','STPTIM11'),
    ('visit2_df','STRTIM12'),
    ('visit2_df','STPTIM12'),
    ('visit2_df','STRTIM22'),
    ('visit2_df','STPTIM22'),
    # ('visit2_df','STRTIM32'),
#     ('visit2_df','STPTIM32'),
    ]
    format_2_cols = [
    ('baseline_df','SPSCTIM0'),
    ('baseline_df','HPSCTIM0'),
    ('visit1_df','SPSCTIM1'),
    ('visit1_df','HPSCTIM1'),
    ('visit2_df','SPSCTIM2'),
    ]

    for coltuple in format_1_cols:
        _convert_dt(*coltuple,dict_of_dfs,'%H:%M:%S')
    for coltuple in format_2_cols:
        _convert_dt(*coltuple,dict_of_dfs,'0:%H:%M')

# %% [markdown]
# # 4. Thinking about data quality

# %% [markdown]
# ## 4a. Looking at data richness by column

# %% [markdown]
# Lets assume that a column over 95% null is less useful for analytics due to a smaller sample size. Quantifying them:

# %%
def get_nulls_ratios(dict_of_dfs): 
    out = {}
    for name, df in dfs.items():
        nulls = (df.isnull().mean() *100).round(2)
        out[name + 'nulls_stats'] = (
            pd.DataFrame(
                nulls[nulls>=95]
            )
            .reset_index()
            .rename(columns = {'index':'colname',0:'percent_null'})
        )
    return out

# %% [markdown]
# We may want to remove any columns over 97.5 null to reduce the dimensions of our data.

# %%
def filter_out_nans_mutates(dict_of_dfs):
    names = ['baseline_df','visit1_df','visit2_df']
    for name in names:
        cols_to_drop = dict_of_dfs[name + 'nulls_stats']
        cols_to_drop = list(cols_to_drop[cols_to_drop.percent_null > 97.5].colname)
        dict_of_dfs[name] = dict_of_dfs[name].drop(columns=cols_to_drop)

# %% [markdown]
# ## 4. Quantify how columns are shared between tables

# %%
def get_clean_column_names(dfname, df,df_suffix_dict):
    
    suffix = df_suffix_dict[dfname]
    return [re.sub(f'{suffix}$','',col) for col in df.columns]

def get_columns_in_a_not_in_b(dict_of_dfs,dfname_a,dfname_b):
    df_suffix_dict = {'baseline_df' : '0', 'visit1_df' : '1','visit2_df': '2'}
    cleaned_columns_a = get_clean_column_names(dfname_a, dict_of_dfs[dfname_a], df_suffix_dict)
    cleaned_columns_b = get_clean_column_names(dfname_b, dict_of_dfs[dfname_b], df_suffix_dict)
    set_difference = set(cleaned_columns_a).difference(set(cleaned_columns_b))
    out = pd.DataFrame({'columns':[col+df_suffix_dict[dfname_a] for col in set_difference]})
    return out

# %% [markdown]
# This is a much smaller intersections in columns than expected- after interrogating the column names there are clearly suffixes relating to the stage of the study. Let's get rid of them, as we have that information at the df level.

# %%
get_columns_in_a_not_in_b(dfs,'visit1_df','visit2_df')
# Out:
#       columns
# 0     CVRDAY1
# 1    GOWRONG1
# 2    OLDMOVE1
# 3    LESSPRE1
# 4    TPARESU1
# ..        ...
# 61   IMAGNOL1
# 62  FAILUREA1
# 63   GOODOLD1
# 64   APOARES1
# 65   CHOLRES1
#
# [66 rows x 1 columns]

# %% [markdown]
# This looks more reasonable (in conunction with the documentation provided, I am happy that no info was lost at this stage). Let's see how that compares to baseline:

# %%
get_columns_in_a_not_in_b(dfs,'visit1_df','baseline_df')
# Out:
#       columns
# 0       SEX81
# 1     RELAT41
# 2    MOMBORN1
# 3    BCORIEN1
# 4    SIDEEFF1
# ..        ...
# 361  BCPTWI21
# 362  FARTHER1
# 363  CHILDRE1
# 364  REGPERI1
# 365  RWRDREL1
#
# [366 rows x 1 columns]

# %% [markdown]
# Accounting for the suffixes, the baseline table contains a lot of data not in the visit tables, which is not unexpected

# %% [markdown]
# ## 5. Check state of SWANID

# %% [markdown]
# First make sure that no SWANID in visits are not present in baseline

# %%
set(visit1_df['SWANID']).difference(set(baseline_df['SWANID']))
# Out:
# set()

# %%
set(visit2_df['SWANID']).difference(set(baseline_df['SWANID']))
# Out:
# set()

# %% [markdown]
# Good. Lets also make sure they are always unique per table:

# %%
for name, df in dfs.items():
    print(f'{name}: {df.SWANID.nunique()/df.SWANID.shape[0]}')
# Out:
# baseline_df: 1.0
# visit1_df: 1.0
# visit2_df: 1.0

# %% [markdown]
# See how SWANIDs are conserved throughout the study - how many drop off at each stage:

# %%
def get_cohort_funnel_stats(dfs):
    total = len(dfs['baseline_df']['SWANID'])
    vis1 = len(set(dfs['baseline_df']['SWANID']).intersection(set(dfs['visit1_df']['SWANID'])))
    vis2=len(set(dfs['baseline_df']['SWANID']).intersection(set(dfs['visit1_df']['SWANID'])).intersection(set(dfs['visit2_df']['SWANID'])))
    cohort = pd.DataFrame({'stage':['baseline','visit1','visit2'], 'subjects':[total,vis1,vis2]})
    return cohort

# %% [markdown]
# ## Joining datasets

# %%
def set_swanid_index_mutates(dfs):
    for name in ['baseline_df','visit1_df','visit2_df']:
        dfs[name].set_index('SWANID',inplace=True)
        
def drop_redundant_cols_mutates(dfs):
    drop_dict = {'baseline_df': ['VISIT'],'visit1_df': ['VISIT','RACE'], 'visit2_df': ['VISIT','RACE']}
    for dfname, cols in drop_dict.items():
        dfs[dfname] = dfs[dfname].drop(columns=cols)

# %%
def join_visits_mutates_(dfs):
    full_data = dfs['baseline_df'].join(dfs['visit1_df'],how = 'left',).join(dfs['visit2_df'], how='left')
    dfs['full_data'] = full_data

# %% [markdown]
# NB - running the above left joins, even after filtering out columns over 97.5% null, exceeds data limits in postgres. Some kind of data lake (e.g. s3) or data warehouse (e.g. Redshift) might be preferable to store this joined data in reality. However, sticking to the limits my Postgres container, I will load the tables seperately into the database.

# %% [markdown]
# ## Testing

# %% [markdown]
# Now we have some data processing functions, we ideally want 100% unit test coverage of them. Given the confines of this task, and the fact that we are developing in Jupyter, let's sketch out what some of our unit tests might look like (when included in a pytest testing suite).

# %%
def test_strip_whitespace():
    _in = pd.DataFrame({
        'col1':[' one', '   . ', 'two', ' '],
        'col2':[1,2,3]
    })
    target = pd.DataFrame({
        'col1':['one', '.', 'two', ''],
        'col2':[1,2,3]
    })
    out = _test_strip_whitespace(df)
    pd.testing.assert_frame_equal(out,target)

def test_clean_nans(df):
    _in = pd.DataFrame({
        'col1':['one','-1','two', ''],
        'col2':['three','-1','four', '.'],
    })
    target = pd.DataFrame({
        'col1':['one',np.nan,'two', np.nan],
        'col2':['three',np.nan,'four', np.nan],
    })
    out = _test_strip_whitespace(df)
    pd.testing.assert_frame_equal(out,target)

test_strip_whitespace()
test_clean_nans()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-2c838aa25034> in <module>
#      23     pd.testing.assert_frame_equal(out,target)
#      24
# ---> 25 test_strip_whitespace()
#      26 test_clean_nans()
#
# <ipython-input-21-2c838aa25034> in test_strip_whitespace()
#       1 def test_strip_whitespace():
# ----> 2     _in = pd.DataFrame({
#       3         'col1':[' one', '   . ', 'two', ' '],
#       4         'col2':[1,2,3]
#       5     })
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/internals/construction.py in extract_index(data)
#     399             lengths = list(set(raw_lengths))
#     400             if len(lengths) > 1:
# --> 401                 raise ValueError("arrays must all be same length")
#     402
#     403             if have_dicts:
#
# ValueError: arrays must all be same length

# %% [markdown]
# ## Step 2: Data aggregation and presentation
#
# Now you have a basic understanding of the data, the next step is to **build a simple 1 page dashboard that summarises the key characteristics of the datasets**.
#
# For this task, you will need to consider the following areas:
# - How to aggregate the 3 datasets into one data structure (e.g. a database) that can be queried (with your chosen programming language)
# - What exhibits to display
# - How to transform the data for the selected exhibits
# - How to host the dashboard (note: the dashboard does not require a public URL, you can demo on your local machine)
#
# ##### To help simplify this task, please use the following guidelines:
# - Stick to a 1 page layout and do not try and prepare more than 6 exhibits
# - Don't worry about 'perfect' styling - we understand this can take a lot of time and we're most interested in your overall approach and the core components of your implementation
#
# Your implementation will likely require writing code outside of the Jupyter notebook environment.
# So, in this notebook please just provide a summary of your approach and add written detail for what else you would do that you haven't included.
# As in step 1, in your written code, please include inline code comments or markdown to explain your approach.

# %% [markdown]
# # Summary

# %% [markdown]
# Through Section 1, we have some metadata related info that we can assume is of some use to our data consumers, as well as some simple data processing that can be the first step towards an ETL pipeline!
#
# So, my data output will be a metadata/QA related dashboard, and some slightly more production-ready code to transform the data.
#
# For the dashboard, I will be using JupyterDash, which allows you to develop Dash apps within a jupyter environment (seemed like the ideal tool for this problem)

# %% [markdown]
# ## Extract

# %%
baseline_df = pd.read_csv("data/swan_1996_97_baseline.csv")
visit1_df = pd.read_csv("data/swan_1997_99_visit1.csv")
visit2_df = pd.read_csv("data/swan_1998_00_visit2.csv")
dfs = {'baseline_df': baseline_df, 'visit1_df': visit1_df,'visit2_df': visit2_df}

# %% [markdown]
# ## Transform

# %%
dfs = convert_bools(dfs)
dfs = strip_whitespace(dfs)
dfs = clean_nans(dfs)
dfs = {**dfs,**get_nulls_ratios(dfs)}
filter_out_nans_mutates(dfs)
mutate_dfs_convert_dts(dfs)
drop_redundant_cols_mutates(dfs)
dfs = {**dfs, **{'cols_in_visit1_not_in_baseline':get_columns_in_a_not_in_b(dfs,'visit1_df','baseline_df')}}
dfs = {**dfs, **{'cols_in_visit2_not_in_visit1':get_columns_in_a_not_in_b(dfs,'visit2_df','visit1_df')}}
dfs = {**dfs, **{'cohort_funnel_stats': get_cohort_funnel_stats(dfs)}}
# set_swanid_index_mutates(dfs)
# join_visits_mutates_(dfs)
#Create insights

# %% [markdown]
# ## Load

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:postgres@db:5432/postgres')
for name, df in dfs.items():
    df.to_sql(name,engine,if_exists ='replace',index=False)
